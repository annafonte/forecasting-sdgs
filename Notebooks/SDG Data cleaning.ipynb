# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import os
import regex as re

# %% [markdown]
# ### Importing excel files

# %%
excel = pd.ExcelFile("../../../Documents/Ironhack/Project4/SDR2020Database.xlsx")
excel1 = pd.ExcelFile("../../../Documents/Ironhack/Project4/2019GlobalIndexResults (1).xlsx")
excel2 = pd.ExcelFile("../../../Documents/Ironhack/Project4/2018GlobalIndexResults.xlsx")
excel3 = pd.ExcelFile("../../../Documents/Ironhack/Project4/2017GlobalIndexResults.xlsx")
excel4 = pd.ExcelFile("../../../Documents/Ironhack/Project4/2016GlobalIndexResults.xlsx")

# %%
data2020 = pd.read_excel(excel, "SDR2020 Data")
data2019 = pd.read_excel(excel1, "SDR2019 Data")
data2018 = pd.read_excel(excel2)
data2017 = pd.read_excel(excel3)
data2016 = pd.read_excel(excel4)

# %% [markdown]
# ### Cleaning data from 2016

# %%
data2016.columns = map(str.lower, data2016.columns)

# %%
lst6 = [2]
for i in range(10,89):
    lst6.append(i)

# %%
indicators2016 = data2016.iloc[:, lst6]

# %%
indicators2016
# Out:
#                   countryname  sdg1_190day_im  sdg1_oecdpov  sdg2_crlyld  \
# 0                      Sweden        0.000000           9.0       5.6496
# 1                     Denmark        0.000000           6.0       6.6049
# 2                      Norway        0.000000           8.0       4.3120
# 3                     Finland        0.000000           7.0       3.6897
# 4                 Switzerland        0.000000          10.0       6.7271
# ..                        ...             ...           ...          ...
# 144                      Chad       38.430000           NaN       0.9410
# 145                     Niger       50.340000           NaN       0.4360
# 146          Congo, Dem. Rep.       77.180000           NaN       0.7628
# 147                   Liberia       68.639999           NaN       1.0773
# 148  Central African Republic       66.269997           NaN       1.6492
#
#      sdg2_nue  sdg2_obesity  sdg2_stunting  sdg2_undernsh_im  sdg2_wasting  \
# ...

# %%
indicators2016.columns
# Out:
# Index(['countryname', 'sdg1_wpc', 'sdg1_oecdpov', 'sdg2_crlyld', 'sdg2_snmi',
#        'sdg2_obesity', 'sdg2_stunting', 'sdg2_undernsh', 'sdg2_wasting',
#        'sdg3_fertility', 'sdg3_lifee', 'sdg3_matmort', 'sdg3_neonat',
#        'sdg3_phys', 'sdg3_smoke', 'sdg3_swb', 'sdg3_tb', 'sdg3_traffic',
#        'sdg3_u5mort', 'sdg3_vac', 'sdg4_literacy', 'sdg4_pisa', 'sdg4_primary',
#        'sdg4_schlyrs', 'sdg4_tertiary', 'sdg4_upsec', 'sdg5_contra',
#        'sdg5_edat', 'sdg5_lfpr', 'sdg5_parl', 'sdg5_paygap', 'sdg6_freshwat',
#        'sdg6_water', 'sdg6_sanita', 'sdg7_co2twh', 'sdg7_elecac',
#        'sdg7_cleanfuel', 'sdg7_ren', 'sdg8_adjgrowth', 'sdg8_atms',
#        'sdg8_clabor_im', 'sdg8_empop', 'sdg8_unemp', 'sdg8_yneet',
#        'sdg9_infrqual', 'sdg9_intuse', 'sdg9_lpi', 'sdg9_mobuse',
#        'sdg9_patents', 'sdg9_rdres', 'sdg9_rdres', 'sdg10_adjgini',
#        'sdg10_justice', 'sdg10_palma', 'sdg11_pipedwat', 'sdg11_pm25',
# ...

# %%
indicators2016.rename(columns={"sdg1_190day_im" : "sdg1_wpc",
                               "sdg2_nue":"sdg2_snmi",
                               "sdg2_undernsh_im":"sdg2_undernsh",
                               "sdg3_hale":"sdg3_lifee",
                              "sdg6_impsan":"sdg6_water",
                              "sdg6_impwat":"sdg6_sanita",
                               'sdg7_nsfuelac':"sdg7_cleanfuel",
                               "sdg9_logperf":"sdg9_lpi",
                               "sdg9_rd_im":"sdg9_rdres",
                               "sdg10_gini":"sdg10_adjgini",
                               "sdg13_co2pcap":"sdg13_co2pc",
                               "sdg16_homicide":"sdg16_homicides"}, inplace=True)

# %%
indicators2016.to_csv("../Project4/indicators2016.csv", index=False)

# %%
print([i for i in indicators2020.columns])
# Out:
# ['Country', 'sdg1_wpc', 'sdg1_320pov', 'sdg1_oecdpov', 'sdg2_undernsh', 'sdg2_stunting', 'sdg2_wasting', 'sdg2_obesity', 'sdg2_trophic', 'sdg2_crlyld', 'sdg2_snmi', 'sdg2_yieldgap', 'sdg3_matmort', 'sdg3_neonat', 'sdg3_u5mort', 'sdg3_tb', 'sdg3_hiv', 'sdg3_ncds', 'sdg3_pollmort', 'sdg3_traffic', 'sdg3_lifee', 'sdg3_fertility', 'sdg3_births', 'sdg3_vac', 'sdg3_uhc', 'sdg3_swb', 'sdg3_region', 'sdg3_incomeg', 'sdg3_smoke', 'sdg4_primary', 'sdg4_second', 'sdg4_literacy', 'sdg4_earlyedu', 'sdg4_tertiary', 'sdg4_pisa', 'sdg4_socioec', 'sdg4_science', 'sdg4_resil', 'sdg5_familypl', 'sdg5_edat', 'sdg5_lfpr', 'sdg5_parl', 'sdg5_paygap', 'sdg5_unpaid', 'sdg6_water', 'sdg6_sanita', 'sdg6_freshwat', 'sdg6_wastewat', 'sdg6_scarcew', 'sdg6_safewat', 'sdg6_safesan', 'sdg7_elecac', 'sdg7_cleanfuel', 'sdg7_co2twh', 'sdg7_ren', 'sdg8_adjgrowth', 'sdg8_slavery', 'sdg8_accounts', 'sdg8_unemp', 'sdg8_impacc', 'sdg8_empop', 'sdg8_yneet', 'sdg9_intuse', 'sdg9_mobuse', 'sdg9_lpi', 'sdg9_qs', 'sdg9_articles
# ...

# %% [markdown]
# ### Cleaning 2017 dataset

# %%
data2016
# Out:
#       id  uncode               countryname  sdgi_rank  sdgi_score  \
# 0    SWE     752                    Sweden          1   84.529419
# 1    DNK     208                   Denmark          2   83.876137
# 2    NOR     578                    Norway          3   82.314545
# 3    FIN     246                   Finland          4   80.997849
# 4    CHE     756               Switzerland          5   80.873856
# ..   ...     ...                       ...        ...         ...
# 144  TCD     148                      Chad        145   31.790310
# 145  NER     562                     Niger        146   31.424807
# 146  COD     180          Congo, Dem. Rep.        147   31.291214
# 147  LBR     430                   Liberia        148   30.489857
# 148  CAF     140  Central African Republic        149   26.102402
#
#      geometricrank  geometricscore   unreg         unregsub sdgiregion  ...  \
# 0                1       83.671783  Europe  Northern Europe       OECD  ...
# ...

# %%
for i in range(len(data2017.columns)):
    print(i)
    print(data2017.columns[i])

# %%
## Dropping useless columns
col = list(data2017.columns)
normalized_columns = [col for col in data2017 if col.find('Normalised')>=0]
data2017.drop(normalized_columns, inplace=True, axis=1)
avg_columns = [col for col in data2017 if col.find('Average score')>=0]
data2017.drop(avg_columns, inplace=True, axis=1)

# %%
lst1 = [0]
for i in range(21,117):
    lst1.append(i)

# %%
indicators2017 = data2017.iloc[:, lst1]

# %%
indicators2017.rename(columns={"Poverty headcount ratio at $1.90/day (%)" : "sdg1_wpc",
                     "Poverty headcount ratio at $3.20/day (% population)" : "sdg1_320pov",
                     "Poverty rate after taxes and transfers, Poverty line 50% (% populatio": "sdg1_oecdpov",
                     "Prevalence of undernourishment (%)" : "sdg2_undernsh",
                     "Prevalence of stunting, under-5s (%)":"sdg2_stunting",
                     "Prevalence of wasting, under-5s (%)":"sdg2_wasting",
                     "Prevalence of adult obesity (%)" : "sdg2_obesity",
                     "Human Trophic Level (best 2 - 3 worst)":"sdg2_trophic",
                     "Cereal yield (t/ha)" : "sdg2_crlyld",
                     'Sust. Nitrogen Management Index (0-1)' :"sdg2_snmi",          
                     "Yield gap closure (%)" : "sdg2_yieldgap",
                     "Maternal mortality (per 100,000 live births) ":"sdg3_matmort",
                     "Neonatal mortality (per 1000 live births)":"sdg3_neonat",
                     "Under-5 mortality (per 1000 live births)":"sdg3_u5mort",
                     "Incidence of tuberculosis (per 100,000)":"sdg3_tb",
                     "HIV incidence (per 1,000)":"sdg3_hiv",
                     'Death rate from NCDs (per 100,000)' : "sdg3_ncds",
                     'Death rate from household and ambient pollution (per 100,000)' : "sdg3_pollmort",
                     'Traffic deaths (per 100,000)':"sdg3_traffic",
                     'Healthy life expectancy at birth (years)':"sdg3_lifee",
                     "Adolescent fertility (births per 1,000)":"sdg3_fertility",
                     "Births attended by skilled health personnel (%)":"sdg3_births",
                     "Infants who receive 2 WHO-recommended vaccines (min % of DTP3 & MCV1)": "sdg3_vac",
                     "Universal health coverage tracer index (0-100)":"sdg3_uhc",
                     "Subjective wellbeing (0-10)":"sdg3_swb",
                     "Gap in life expectancy at birth among regions (years)":"sdg3_region",
                     "Gap in self-reported health by income (0-100)":"sdg3_incomeg",
                     "[OECD-only] Daily smokers (%, aged 15+)":"sdg3_smoke",
                     "Net primary school enrolment rate (%)":"sdg4_primary",
                      "Expected years of schooling (years)":"sdg4_schlyrs",
                     "Lower secondary completion rate (%)":"sdg4_second",
                     "Literacy rate of 15-24 year olds (%)":"sdg4_literacy",
                     "Enrollment in early childhood learning program (% ages 4-6)":"sdg4_earlyedu",
                     "[OECD-only] Population with tertiary education (%)":"sdg4_tertiary",
                     "[OECD-only] Average PISA score across Maths/Reading/Science(0-600)":"sdg4_pisa",           
                     "Percentage of variation in science performance explained by students'":"sdg4_socioec",
                     "Students performing below level 2 in science (%)":"sdg4_science",
                     "Resilient students (%)":"sdg4_resil",
                     "Unmet demand for contraceptives (%)":"sdg5_familypl",
                     "Female years of schooling (% male)":"sdg5_edat",
                     "Female labor force participation (% male)":"sdg5_lfpr",
                     "Women in national parliaments (%)":"sdg5_parl",
                     "[OECD-only] Gender wage gap (% male wage)":"sdg5_paygap",
                     "Gender gap in minutes spent per day doing unpaid work (minutes)":"sdg5_unpaid",
                     "Access to improved water (%)":"sdg6_water",
                     "Access to improved sanitation (%)":"sdg6_sanita",
                     "Freshwater withdrawal (%) ":"sdg6_freshwat",
                     "Wastewater treated (%)":"sdg6_wastewat",
                     "[Spillover] Imported groundwater depletion (m3/year/capita)":"sdg6_scarcew",
                     "Population using safely managed water services (%)":"sdg6_safewat",
                     "Population using safely managed sanitation services (%)":"sdg6_safesan",
                     "Access to electricity (%)":"sdg7_elecac",
                     "Access to non-solid fuels (%)":"sdg7_cleanfuel",      
                     "CO2 from fuels combustion / elec. output (MtCO2/TWh)":"sdg7_co2twh",
                     "[OECD-only] Renewable energy in final consumption (%)":"sdg7_ren",
                     "Adjusted growth rate (%)":"sdg8_adjgrowth",                      
                     "Slavery score (0-100)":"sdg8_slavery",
                     "Access to bank account or mobile-money service (% adult pop.)":"sdg8_accounts",
                     "[Global-only] Unemployment rate (%)":"sdg8_unemp",
                     "Fatal work-related accidents embodied in imports (deaths per 100,000)":"sdg8_impacc",
                     "[OECD-only] Employment-to-population ratio (%)":"sdg8_empop",
                     "[OECD-only] Youth not in employment, education, training (%)":"sdg8_yneet",
                     "GCI: Quality of overall infrastructure (1-7)":"sdg9_infrqual",
                     "Internet use (%)":"sdg9_intuse",                               
                     "Mobile broadband subscriptions (per 100)":"sdg9_mobuse",
                     "LPI: Infrastructure Quality (1-5)":"sdg9_lpi",
                     "Top 3 University Rankings (0-100)":"sdg9_qs",
                     "# of scientific and technical journal articles (per capita)":"sdg9_articles",
                     "Government R&D expenditures (% GDP)":"sdg9_rdex",
                     "[OECD-only] R&D researchers (per 1000 employed)":"sdg9_rdres",
                     "[OECD-only] Patent applications (per 100,000 people)":"sdg9_patents",
                     "Gap in internet access by income (%)":"sdg9_netacc",
                     "Women in science and engineering (%)":"sdg9_womensci",
                     "Gini index (0-100)":"sdg10_adjgini",
                     "[OECD-only] PISA Social Justice Index (0-10)":"sdg10_justice",
                     "[OECD-only] Palma ratio": "sdg10_palma",
                     "Improved water source, piped (%) ":"sdg11_pipedwat",
                     "Elderly Poverty Rate (%)":"sdg10_elder",
                     "PM2.5 in urban areas (µg/m3)":"sdg11_pm25",
                     "Improved water source, piped (% urban population with access)":"sdg11_pipedwat",
                     "Satisfaction with public transport (%)":"sdg11_transport",
                     "[OECD-only] Rent burden (% of disposable income)":"sdg11_rentover",
                     "[Global-only] Municipal solid waste (kg/person/year)":"sdg12_msw",
                     "E-waste generated (kg/person/year)":"sdg12_ewaste",        
                     "Production-based SO2 emissions (t/capita)":"sdg12_so2prod",
                     "[Spillover] Net imported SO2 emissions (t/capita) ":"sdg12_so2import",
                     "Production-based reactive nitrogen emissions (kg/capita)":"sdg12_prodnitro",
                     "[Spillover] Net imported emissions of reactive nitrogen (kg/capita)":"sdg12_reacnitro",
                     "[OECD-only] Non-recycled municipal solid waste (kg/person/year)":"sdg12_mswrecycl",
                     "CO2 emissions from energy (tCO2/capita)":"sdg13_co2pc",
                     "Climate change vulnerability index (0-1)":"sdg13_ccvm",
                     "[Spillover] Imported emissions, tech-adjusted (tCO2/capita)":"sdg13_co2import",
                     "CO2 emissions embodied in fossil fuel exports (kg/capita)":"sdg13_co2export",
                     "[OECD-only] Effective Carbon Rate (€/tCO2)":"sdg13_ecr",
                     "Ocean Health Index - Biodiversity (0-100)":"sdg14_biodiv",
                     "Marine sites, mean area protected (%)":"sdg14_cpma",
                     "Ocean Health Index - Fisheries (0-100)":"sdg14_fish",
                     "Ocean Health Index - Clean waters (0-100)":"sdg14_cleanwat",
                     "Fish stocks overexploited or collapsed (%)":"sdg14_fishstocks",
                     "Fish caught by trawling (%)":"sdg14_trawl",
                     "Marine biodiversity threats embodied in imports (per million population)":"sdg14_biomar",
                     "Terrestrial sites, mean area protected (%)":"sdg15_cpta",
                     "Freshwater sites, mean area protected(%)":"sdg15_cpfa",
                     "Annual change in forest area (%)":"sdg15_forchg",              
                     "Red List Index of species survival (0-1)":"sdg15_redlist",
                     "[Spillover] Imported biodiversity impacts (species lost per million people)":"sdg15_biofrwter",
                     "GCI: Government efficiency (1-7)":"sdg16_goveff",
                     "Homicides (per 100,000)":"sdg16_homicides",
                     "Unsentenced detainees (%)":"sdg16_detain",
                     "Feel safe walking at night (%)":"sdg16_safe",
                     "GCI: Property rights (1-7)":"sdg16_prs",
                     "Registered births (%)":"sdg16_u5reg",
                     "Corruption Perception Index (0-100)":"sdg16_cpi",
                     "Child labor (%)":"sdg16_clabor",
                     "[Spillover] Weapons Exports (const. 1990 US, per 100,000 people)":"sdg16_weaponsexp",
                     "Freedom of Press Index (best 0 - 100 worst)":"sdg16_rsf",
                     "Prison population (per 100,000)":"sdg16_prison",
                     "Health & Education spending (% GDP)":"sdg17_govex",
                     "For high-income and all OECD DAC countries: International concessional public fi":"sdg17_oda",
                     "Other countries : Government Revenue excluding Grants (% GDP)":"sdg17_govrev",
                     "[Spillover] Tax Haven Score (best 0-5 worst)":"sdg17_cohaven",
                     "[HICs only] [Spillover] Official development assistance (% GNI)":"sdg17_govspd",
                     "[OECD-only][Spillover] Financial Secrecy Score (0-100)":"sdg17_secrecy",
                     "Shifted profits of multinationals (US$ billion)":"sdg17_sprofit"}, inplace=True)

# %%
[i for i in indicators2017.columns if i in indicators2017.columns]

# %%
indicators2017.to_csv("../Project4/indicators2017.csv", index=False)

# %% [markdown]
# ### Cleaning 2018 dataset

# %%
col = list(data2018.columns)
normalized_columns = [col for col in data2018 if col.find('Normalised')>=0]
data2018.drop(normalized_columns, inplace=True, axis=1)
goal_columns = [col for col in data2018 if col.find('Goal')>=0]
data2018.drop(goal_columns, inplace=True, axis=1)
data2018.drop("Projected poverty headcount ratio at $1.90/day (%) in 2030", axis=1, inplace=True)

# %%
lst2 = [0]
for i in range(12,122):
    lst2.append(i)

# %%
indicators2018 = data2018.iloc[:, lst2]

# %%
indicators2018.rename(columns=lambda x: re.sub(r'^OECD only : ',r'',x), inplace=True)

# %%
indicators2018.rename(columns={"Poverty headcount ratio at $1.90/day (%)" : "sdg1_wpc",
                     "Poverty headcount ratio at $3.20/day (% population)" : "sdg1_320pov",
                     "Poverty line 50% (%)": "sdg1_oecdpov",
                     "Prevalence of undernourishment (%)" : "sdg2_undernsh",
                     "Prevalence of stunting, under-5s (%)":"sdg2_stunting",
                     "Prevalence of wasting, under-5s (%)":"sdg2_wasting",
                     "Prevalence of adult obesity (%)" : "sdg2_obesity",
                     "Human Trophic Level (best 2 - 3 worst)":"sdg2_trophic",
                     "Cereal yield (t/ha)" : "sdg2_crlyld",
                     'Sust. Nitrogen Management Index' :"sdg2_snmi",
                     "Yield gap closure (%)" : "sdg2_yieldgap",
                     "Maternal mortality (per 100,000 live births) ":"sdg3_matmort",
                     "Neonatal mortality (per 1000 live births)":"sdg3_neonat",
                     "Under 5 mortality (per 1000 live births)":"sdg3_u5mort",
                     "Incidence of tuberculosis (per 100,000)":"sdg3_tb",
                     "HIV prevalence (per 1,000)":"sdg3_hiv",
                     'Death rate from NCDs (per 100,000)' : "sdg3_ncds",
                     'Death rate from household and ambient pollution (per 100,000)' : "sdg3_pollmort",
                     'Traffic deaths (per 100,000)':"sdg3_traffic",
                     'Healthy life expectancy at birth (years)':"sdg3_lifee",
                     "Adolescent fertility (births per 1,000)":"sdg3_fertility",
                     "Births attended by skilled health personnel (%)":"sdg3_births",
                     "Infants who receive 2 WHO vaccines (%)": "sdg3_vac",
                     "UHC Tracer Index (0-100)":"sdg3_uhc",
                     "Subjective wellbeing (0-10)":"sdg3_swb",
                     "Gap in life expectancy (years)":"sdg3_region",
                     "Gap in self-reported health by income":"sdg3_incomeg",
                     "Daily smokers (%, age 15+)":"sdg3_smoke",
                     "Net primary school enrolment rate (%)":"sdg4_primary",
                     "Lower secondary completion rate (%)":"sdg4_second",
                    "Mean years of schooling (years)":"sdg4_schlyrs",
                     "Literacy rate of 15-24 year olds (%)":"sdg4_literacy",
                     "Enrollment in early childhood learning program (% ages 4-6)":"sdg4_earlyedu",
                     "Population with tertiary education (%)":"sdg4_tertiary",
                     "PISA score (0 -600)":"sdg4_pisa",           
                     "Science performance explained by socioeconomic background":"sdg4_socioec",
                     "Low science performance (%)":"sdg4_science",
                     "Resilient students (%)":"sdg4_resil",
                     "Unmet demand for contraceptives (%)":"sdg5_familypl",
                     "Female years of schooling (% male)":"sdg5_edat",
                     "Female labor force participation (% male)":"sdg5_lfpr",
                     "Women in national parliaments (%)":"sdg5_parl",
                     "Gender wage gap (% male wage)":"sdg5_paygap",
                     "Gender gap in minutes spent per day doing unpaid work (minutes)":"sdg5_unpaid",
                     "Access to improved water (%)":"sdg6_water",
                     "Access to improved sanitation (%)":"sdg6_sanita",
                     "Freshwater withdrawal (%) ":"sdg6_freshwat",
                     "Wastewater treated (%)":"sdg6_wastewat",
                     "Imported groundwater depletion (m3/year/capita)":"sdg6_scarcew",
                     "Population using safely managed water services (%)":"sdg6_safewat",
                     "Population using safely managed sanitation services (%)":"sdg6_safesan",
                     "Population using at least basic drinking water services (%)":"sdg6_water",
                     "Access to electricity (%)":"sdg7_elecac",
                     "Access to clean fuels (%)":"sdg7_cleanfuel",      
                     "CO2 from fuels & electricity (MtCO2/TWh)":"sdg7_co2twh",
                     "Renewable energy in final consumption (%)":"sdg7_ren",
                     "Adjusted growth rate (%)":"sdg8_adjgrowth",                      
                     "Slavery Score (0-100)":"sdg8_slavery",
                     "Access to bank account or mobile-money (% adult pop.)":"sdg8_accounts",
                     "Unemployment rate (%)":"sdg8_unemp",
                     "Fatal work-related accidents embodied in imports (deaths per 100,000)":"sdg8_impacc",
                     "Employment-to-population ratio (%)":"sdg8_empop",
                     "Youth not in employment, education, training (%)":"sdg8_yneet",
                     "Quality of overall infrastructure (1-7)":"sdg9_infrqual",
                     "Internet use (%)":"sdg9_intuse",                               
                     "Mobile broadband subscriptions (per 100)":"sdg9_mobuse",
                     "Logistics Performance Index (1-5)":"sdg9_lpi",
                     "Average of top 3 university rankings (0-100)":"sdg9_qs",
                     "Scientific and technical journal articles (items per bn. PPP$ GDP)":"sdg9_articles",
                     "Government R&D expenditures (% GDP)":"sdg9_rdex",
                     "R&D researchers (per 1000 employed)":"sdg9_rdres",
                     "Triadic Patent Families (per million)":"sdg9_patents",
                     "Gap in internet access by income":"sdg9_netacc",
                     "Women in science and engineering":"sdg9_womensci",
                     "Adjusted Gini Coefficient (0-100)":"sdg10_adjgini",
                     "Palma ratio": "sdg10_palma",
                     "Elderly Poverty Rate (%)":"sdg10_elder",
                     "PM2.5 in urban areas (µg/m3)":"sdg11_pm25",
                     "Improved water source, piped (%) ":"sdg11_pipedwat",
                     "Satisfaction with public transport (%)":"sdg11_transport",
                     "Rent overburden rate (%)":"sdg11_rentover",
                     "Municipal solid waste (kg/person/year)":"sdg12_msw",
                     "E-waste (kg/capita)":"sdg12_ewaste",        
                     "Production-based SO2 emissions (kg/capita)":"sdg12_so2prod",
                     "Net imported SO2 emissions (kg/capita) ":"sdg12_so2import",
                     "Nitrogen production footprint (kg/capita)":"sdg12_prodnitro",
                     "Net imported emissions of reactive nitrogen (kg/capita)":"sdg12_reacnitro",
                     "Non-recycled municipal solid waste (kg/person/year)":"sdg12_mswrecycl",
                     "CO2 emissions from energy (tCO2/capita)":"sdg13_co2pc",
                     "Imported CO2 emissions, tech-adjusted (tCO2/capita)":"sdg13_co2import",
                     "Climate change vulnerability (0-1)":"sdg13_ccvm",
                     "Exported CO2 emissions from fossil fuels (kg/capita)":"sdg13_co2export",
                     "Effective Carbon Rate (€/tCO2)":"sdg13_ecr",
                     "Marine sites, mean protected area (%)":"sdg14_cpma",
                     "Ocean Health Index  - Fisheries (0-100)":"sdg14_fish",
                     "Ocean Health Index - Biodiversity (0-100)":"sdg14_biodiv",
                     "Ocean Health Index - Clean waters (0-100)":"sdg14_cleanwat",
                     "Fish stocks overexploited or collapsed (%)":"sdg14_fishstocks",
                     "Fish caught by trawling (%)":"sdg14_trawl",
                     "Marine biodiversity threats embodied in imports (per million population)":"sdg14_biomar",
                     "Terrestrial sites, mean protected area (%)":"sdg15_cpta",
                     "Freshwater sites, mean protected area (%)":"sdg15_cpfa",
                     "Annual change in forest area (%)":"sdg15_forchg",              
                     "Red List Index of species survival (0-1)":"sdg15_redlist",
                     "Imported biodiversity threats (threats per million)":"sdg15_biofrwter",
                     "Homicides (per 100,000)":"sdg16_homicides",
                     "Unsentenced detainees (%)":"sdg16_detain",
                     "Feel safe walking at night (%)":"sdg16_safe",
                     "Property rights (1-7)":"sdg16_prs",
                     "Registered births (%)":"sdg16_u5reg",
                     "Corruption Perception Index (0-100)":"sdg16_cpi",
                     "Child labor (%)":"sdg16_clabor",
                     "Government efficiency (1-7)":"sdg16_goveff",
                     "Conventional weapons exports (US per 100,000 people)":"sdg16_weaponsexp",
                     "Freedom of Press Index (best 0 - 100 worst)":"sdg16_rsf",
                     "Prison population (per 100,000)":"sdg16_prison",
                     "Health & Education spending (% GDP)":"sdg17_govex",
                     "Official development assistance (% GNI)":"sdg17_govspd",
                     "For high-income and all OECD DAC countries: International concessional public fi":"sdg17_oda",
                     "Tax revenue (% GDP)":"sdg17_govrev",
                     "Tax Haven Score (best 0-5 worst)":"sdg17_cohaven",
                     "Secrecy Score (best 0-100 worst)":"sdg17_secrecy",
                     "Shifted profits of multinationals (US$ billion)":"sdg17_sprofit"}, inplace=True)

# %%
[i for i in indicators2018.columns if i in indicators2018.columns]
# Out:
# ['country',
#  'sdg1_wpc',
#  'sdg2_undernsh',
#  'sdg2_stunting',
#  'sdg2_wasting',
#  'sdg2_obesity',
#  'sdg2_crlyld',
#  'sdg2_snmi',
#  'sdg3_matmort',
#  'sdg3_neonat',
#  'sdg3_u5mort',
#  'sdg3_tb',
#  'sdg3_hiv',
#  'sdg3_ncds',
#  'sdg3_pollmort',
#  'sdg3_traffic',
#  'sdg3_lifee',
#  'sdg3_fertility',
#  'sdg3_births',
#  'sdg3_vac',
#  'sdg3_uhc',
#  'sdg3_swb',
#  'sdg4_primary',
#  'sdg4_schlyrs',
#  'sdg4_literacy',
#  'sdg5_familypl',
#  'sdg5_edat',
#  'sdg5_lfpr',
#  'sdg5_parl',
#  'sdg6_safesan',
#  'Population using at least basic sanitation services (%)',
#  'sdg6_safewat',
#  'sdg6_water',
#  'sdg6_freshwat',
#  'sdg6_scarcew',
#  'sdg7_elecac',
#  'sdg7_cleanfuel',
#  'sdg7_co2twh',
#  'sdg8_adjgrowth',
#  'sdg8_slavery',
#  'sdg8_accounts',
#  'sdg8_unemp',
#  'sdg9_intuse',
#  'sdg9_mobuse',
#  'sdg9_infrqual',
#  'sdg9_lpi',
#  'sdg9_qs',
#  'sdg9_articles',
#  'sdg9_rdex',
#  'sdg10_adjgini',
#  'sdg11_pm25',
#  'sdg11_pipedwat',
#  'sdg11_transport',
# ...

# %%
indicators2018.to_csv("../Project4/indicators2018.csv", index=False)

# %% [markdown]
# ### Cleaning 2019 dataset

# %%
for i in range(len(data2019.columns)):
    print(i)
    print(data2019.columns[i])

# %%
dashboard_columns = [col for col in data2019 if col.find('Dashboard')>=0]
data2019.drop(dashboard_columns, inplace=True, axis=1)
trends_columns = [col for col in data2019 if col.find('Trend')>=0]
data2019.drop(trends_columns, inplace=True, axis=1)
imputation_columns = [col for col in data2019 if col.startswith('imput')]
data2019.drop(imputation_columns, inplace=True, axis=1)
year_columns = [col for col in data2019 if col.startswith('Year')]
data2019.drop(year_columns, inplace=True, axis=1)
normalized_columns = [col for col in data2019 if col.startswith('Normalized')]
data2019.drop(normalized_columns, inplace=True, axis=1)
data2019.drop("People affected by climate-related disasters (per 100,000 population)", axis=1, inplace=True)

# %%
lst = [0]
for i in range(13,126):
    lst.append(i)

# %%
indicators2019 = data2019.iloc[:, lst]

# %%
indicators2019.rename(columns=lambda x: re.sub(r'^OECD only: ',r'',x), inplace=True)

# %%
indicators2019.rename(columns={"Poverty headcount ratio at $1.90/day (% population)" : "sdg1_wpc",
                     "Poverty headcount ratio at $3.20/day (% population)" : "sdg1_320pov",
                     "Poverty rate after taxes and transfers, Poverty line 50% (% populatio": "sdg1_oecdpov",
                     "Prevalence of undernourishment (% population)" : "sdg2_undernsh",
                     "Prevalence of stunting (low height-for-age) in children under 5 years of age (%)":"sdg2_stunting",
                     "Prevalence of wasting in children under 5 years of age (%)":"sdg2_wasting",
                     "Prevalence of obesity, BMI ≥ 30 (% adult population)" : "sdg2_obesity",
                     "Human Trophic Level (best 2 - 3 worst)":"sdg2_trophic",
                     "Cereal yield (t/ha)" : "sdg2_crlyld",
                     'Sustainable Nitrogen Management Index' :"sdg2_snmi",
                     "Yield gap closure (%)" : "sdg2_yieldgap",
                     "Maternal mortality rate (per 100,000 live births) ":"sdg3_matmort",
                     "Neonatal mortality rate (per 1,000 live births)":"sdg3_neonat",
                     "Mortality rate, under-5 (per 1,000 live births)":"sdg3_u5mort",
                     "Incidence of tuberculosis (per 100,000 population)":"sdg3_tb",
                     "New HIV infections (per 1,000)":"sdg3_hiv",
                     'Age-standardised death rate due to cardiovascular disease, cancer, diabetes, and' : "sdg3_ncds",
                     'Age-standardised death rate attributable to household air pollution and ambient ' : "sdg3_pollmort",
                     'Traffic deaths rate (per 100,000 population)':"sdg3_traffic",
                     'Life Expectancy at birth (years)':"sdg3_lifee",
                     "Adolescent fertility rate (births per 1,000 women ages 15-19)":"sdg3_fertility",
                     "Births attended by skilled health personnel (%)":"sdg3_births",
                     "Percentage of surviving infants who received 2 WHO-recommended vaccines (%)": "sdg3_vac",
                     "Universal Health Coverage Tracer Index (0-100)":"sdg3_uhc",
                     "Subjective Wellbeing (average ladder score, 0-10)":"sdg3_swb",
                     "Gap in life expectancy at birth among regions (years)":"sdg3_region",
                     "Gap in self-reported health by income (0-100)":"sdg3_incomeg",
                     "Daily smokers (% population age 15+)":"sdg3_smoke",
                     "Net primary enrolment rate (%)":"sdg4_primary",
                     "Lower secondary completion rate (%)":"sdg4_second",
                     "Literacy rate of 15-24 year olds, both sexes (%)":"sdg4_literacy",
                     "Enrollment in early childhood learning program (% ages 4-6)":"sdg4_earlyedu",
                     "Population age 25-34 with tertiary education (%)":"sdg4_tertiary",
                     "PISA score (0-600)":"sdg4_pisa",           
                     "Percentage of variation in science performance explained by students'":"sdg4_socioec",
                     "Students performing below level 2 in science (%)":"sdg4_science",
                     "Resilient students (%)":"sdg4_resil",
                     "Demand for family planning satisfied by modern methods (% women married or in un":"sdg5_familypl",
                     "Ratio of female to male mean years of schooling of population age 25 and above ":"sdg5_edat",
                     "Ratio of female to male labour force participation rate":"sdg5_lfpr",
                     "Seats held by women in national parliaments (%)":"sdg5_parl",
                     "Gender wage gap (Total,\xa0% male median wage)":"sdg5_paygap",
                     "Gender gap in minutes spent per day doing unpaid work (minutes)":"sdg5_unpaid",
                     "Population using at least basic drinking water services (%)":"sdg6_water",
                     "Population using at least basic sanitation services (%)":"sdg6_sanita",
                     "Freshwater withdrawal as % total renewable water resources":"sdg6_freshwat",
                     "Anthropogenic wastewater that receives treatment (%)":"sdg6_wastewat",
                     "Imported groundwater depletion (m3/year/capita)":"sdg6_scarcew",
                     "Population using safely managed water services (%)":"sdg6_safewat",
                     "Population using safely managed sanitation services (%)":"sdg6_safesan",
                     "Access to electricity (% population)":"sdg7_elecac",
                     "Access to clean fuels & technology for cooking (% population)":"sdg7_cleanfuel",
                     "CO2 emissions from fuel combustion / electricity output (MtCO2/TWh)":"sdg7_co2twh",
                     "Share of renewable energy in total final energy consumption (%)":"sdg7_ren",
                     "Adjusted Growth (%)":"sdg8_adjgrowth",                      
                     "Prevalence of Modern Slavery (victims per 1,000 population)":"sdg8_slavery",
                     "Adults (15 years and older) with an account at a bank or other financial institu":"sdg8_accounts",
                     "Unemployment rate (% total labor force)":"sdg8_unemp",
                     "Fatal work-related accidents embodied in imports (deaths per 100,000)":"sdg8_impacc",
                     "Employment-to-Population ratio (%)":"sdg8_empop",
                     "Youth not in employment, education or training (NEET) (%)":"sdg8_yneet",
                     "Population using the internet (%)":"sdg9_intuse",                               
                     "Mobile broadband subscriptions (per 100 inhabitants)":"sdg9_mobuse",
                     "Logistics performance index: Quality of trade and transport-related infrastructu":"sdg9_lpi",
                     "The Times Higher Education Universities Ranking : Average score of top 3 univers":"sdg9_qs",
                     "Number of scientific and technical journal articles (per 1,000 population)":"sdg9_articles",
                     "Research and development expenditure (% GDP)":"sdg9_rdex",
                     "Research and development researchers (per 1,000 employed)":"sdg9_rdres",
                     "Triadic Patent Families filed (per million population)":"sdg9_patents",
                     "Gap in internet access by income (%)":"sdg9_netacc",
                     "Women in science and engineering (%)":"sdg9_womensci",
                     "Gini Coefficient adjusted for top income (1-100)":"sdg10_adjgini",
                     "Palma ratio":"sdg10_palma",
                     "Elderly Poverty Rate (%)":"sdg10_elder",
                     "Annual mean concentration of particulate matter of less than 2.5 microns of diam":"sdg11_pm25",
                     "Improved water source, piped (% urban population with access)":"sdg11_pipedwat",
                     "Satisfaction with public transport (%)":"sdg11_transport",
                     "Rent overburden rate (%)":"sdg11_rentover",
                     "Municipal Solid Waste (kg/day/capita)":"sdg12_msw",
                     "E-waste generated (kg/capita)":"sdg12_ewaste",        
                     "Production-based SO2 emissions (kg/capita)":"sdg12_so2prod",
                     "Imported SO2 emissions (kg/capita) ":"sdg12_so2import",
                     "Nitrogen production footprint (kg/capita)":"sdg12_prodnitro",
                     "Net imported emissions of reactive nitrogen (kg/capita)":"sdg12_reacnitro",
                     "Non-Recycled Municipal Solid Waste (kg/day/capita)":"sdg12_mswrecycl",
                     "Energy-related CO2 emissions per capita (tCO2/capita)":"sdg13_co2pc",
                     "Imported CO2 emissions, technology-adjusted (tCO2/capita)":"sdg13_co2import",
                     "CO2 emissions embodied in fossil fuel exports (kg/capita)":"sdg13_co2export",
                     "Effective Carbon Rate from all non-road energy, excluding emissions f":"sdg13_ecr",
                     "Mean area that is protected in marine sites important to biodiversity (%) ":"sdg14_cpma",
                     "Ocean Health Index Goal - Clean Waters (0-100)":"sdg14_cleanwat",
                     "Percentage of Fish Stocks overexploited or collapsed by EEZ (%)":"sdg14_fishstocks",
                     "Fish caught by trawling (%)":"sdg14_trawl",
                     "Marine biodiversity threats embodied in imports (per million population)":"sdg14_biomar",
                     "Mean area that is protected in terrestrial sites important to biodiversity (%)":"sdg15_cpta",
                     "Mean area that is protected in freshwater sites important to biodiversity (%)":"sdg15_cpfa",
                     "Permanent Deforestation (5 year average annual %)":"sdg15_forchg",
                     "Red List Index of species survival (0-1)":"sdg15_redlist",
                     "Imported biodiversity threats (threats per million population)":"sdg15_biofrwter",
                     "Homicides (per 100,000 population)":"sdg16_homicides",
                     "Unsentenced detainees (%)":"sdg16_detain",
                     "Proportion of the population who feel safe walking alone at night in the city or":"sdg16_safe",
                     "Property Rights (1-7)":"sdg16_prs",
                     "Birth registrations with civil authority, children under 5 years of age (%)":"sdg16_u5reg",
                     "Corruption Perception Index (0-100)":"sdg16_cpi",
                     "Children 5–14 years old involved in child labour (%)":"sdg16_clabor",
                     "Transfers of major conventional weapons (exports) (constant 1990 US$ million per":"sdg16_weaponsexp",
                     "Freedom of Press Index (best 0 - 100 worst)":"sdg16_rsf",
                     "Prison Population (per 100,000 people)":"sdg16_prison",
                     "Government Health and Education spending (% GDP)":"sdg17_govex",
                     "For high-income and all OECD DAC countries: International concessional public fi":"sdg17_oda",
                     "Other countries : Government Revenue excluding Grants (% GDP)":"sdg17_govrev",
                     "Tax Haven Score (best 0-5 worst)":"sdg17_cohaven",
                     "Financial Secrecy Score (best 0-100 worst)":"sdg17_secrecy",
                     "Shifted profits of multinationals (US$ billion)":"sdg17_sprofit"}, inplace=True)

# %%
[i for i in indicators2019.columns if i in indicators2019.columns]

# %%
indicators2019.to_csv("../Project4/indicators2019.csv", index=False)

# %% [markdown]
# ### Cleaning data from 2020

# %%
#Droping the dashboard and trends columns
col = list(data2020.columns)
dashboard_columns = [col for col in data2020 if col.find('Dash')>=0]
data2020.drop(dashboard_columns, inplace=True, axis=1)
trends_columns = [col for col in data2020 if col.find('Trend')>=0]
data2020.drop(trends_columns, inplace=True, axis=1)
imputation_columns = [col for col in data2020 if col.startswith('Imputation')]
data2020.drop(imputation_columns, inplace=True, axis=1)
year_columns = [col for col in data2020 if col.startswith('Year')]
data2020.drop(year_columns, inplace=True, axis=1)
normalized_columns = [col for col in data2020 if col.startswith('Normalized')]
data2020.drop(normalized_columns, inplace=True, axis=1)
goal_columns = [col for col in data2020 if col.startswith('Goal')]
data2020.drop(goal_columns, inplace=True, axis=1)

# %%
lst3 = [0]
for i in range(9,124):
    lst3.append(i)

# %%
indicators2020 = data2020.iloc[:193, lst3]

# %%
## renaming columns
indicators2020.rename(columns={"Poverty headcount ratio at $1.90/day (%)" : "sdg1_wpc",
                     "Poverty headcount ratio at $3.20/day (%)" : "sdg1_320pov",
                     "Poverty rate after taxes and transfers (%)": "sdg1_oecdpov",
                     "Prevalence of undernourishment (%)" : "sdg2_undernsh",
                     "Prevalence of stunting in children under 5 years of age (%)":"sdg2_stunting",
                     "Prevalence of wasting in children under 5 years of age (%)":"sdg2_wasting",
                     "Prevalence of obesity, BMI ≥ 30 (% of adult population)" : "sdg2_obesity",
                     "Human Trophic Level (best 2-3 worst)":"sdg2_trophic",
                     "Cereal yield (tonnes per hectare of harvested land)" : "sdg2_crlyld",
                     "Sustainable Nitrogen Management Index (worst 0-1.41 best)" :"sdg2_snmi",
                     "Yield gap closure (% of potential yield)" : "sdg2_yieldgap",
                     "Maternal mortality rate (per 100,000 live births) ":"sdg3_matmort",
                     "Neonatal mortality rate (per 1,000 live births)":"sdg3_neonat",
                     "Mortality rate, under-5 (per 1,000 live births)":"sdg3_u5mort",
                     "Incidence of tuberculosis (per 100,000 population)":"sdg3_tb",
                     "New HIV infections (per 1,000 uninfected population)":"sdg3_hiv",
                     "Age-standardized death rate due to cardiovascular disease, cancer, diabetes, or " : "sdg3_ncds",
                     "Age-standardized death rate attributable to household air pollution and ambient " : "sdg3_pollmort",
                     "Traffic deaths (per 100,000 population)":"sdg3_traffic",
                     "Life expectancy at birth (years)":"sdg3_lifee",
                     "Adolescent fertility rate (births per 1,000 adolescent females aged 15 to 19)":"sdg3_fertility",
                     "Births attended by skilled health personnel (%)":"sdg3_births",
                     "Percentage of surviving infants who received 2 WHO-recommended vaccines (%)": "sdg3_vac",
                     "Universal health coverage (UHC) index of service coverage (worst 0-100 best)":"sdg3_uhc",
                     "Subjective well-being (average ladder score, worst 0-10 best)":"sdg3_swb",
                     "Gap in life expectancy at birth among regions (years)":"sdg3_region",
                     "Gap in self-reported health status by income (percentage points)":"sdg3_incomeg",
                     "Daily smokers (% of population aged 15 and over)":"sdg3_smoke",
                     "Net primary enrollment rate (%)":"sdg4_primary",
                     "Lower secondary completion rate (%)":"sdg4_second",
                     "Literacy rate (% of population aged 15 to 24)":"sdg4_literacy",
                     "Participation rate in pre-primary organized learning (% of children aged 4 to 6)":"sdg4_earlyedu",
                     "Tertiary educational attainment (% of population aged 25 to 34)":"sdg4_tertiary",
                     "PISA score (worst 0-600 best)":"sdg4_pisa",
                     "Variation in science performance explained by socio-economic status (%)":"sdg4_socioec",
                     "Underachievers in science (% of 15-year-olds) ":"sdg4_science",
                     "Resilient students in science (% of 15-year-olds)":"sdg4_resil",
                     "Demand for family planning satisfied by modern methods (% of females aged 15 to ":"sdg5_familypl",
                     "Ratio of female-to-male mean years of education received (%)":"sdg5_edat",
                     "Ratio of female-to-male labor force participation rate (%)":"sdg5_lfpr",
                     "Seats held by women in national parliament (%)":"sdg5_parl",
                     "Gender wage gap (% of male median wage)":"sdg5_paygap",
                     "Gender gap in time spent doing unpaid work (minutes/day)":"sdg5_unpaid",
                     "Population using at least basic drinking water services (%)":"sdg6_water",
                     "Population using at least basic sanitation services (%)":"sdg6_sanita",
                     "Freshwater withdrawal (% of available freshwater resources)":"sdg6_freshwat",
                     "Anthropogenic wastewater that receives treatment (%)":"sdg6_wastewat",
                     "Scarce water consumption embodied in imports (m³/capita)":"sdg6_scarcew",
                     "Population using safely managed water services (%)":"sdg6_safewat",
                     "Population using safely managed sanitation services (%)":"sdg6_safesan",
                     "Population with access to electricity (%)":"sdg7_elecac",
                     "Population with access to clean fuels and technology for cooking (%)":"sdg7_cleanfuel",
                     "CO₂ emissions from fuel combustion for electricity and heating per total electri":"sdg7_co2twh",
                     "Share of renewable energy in total primary energy supply (%)":"sdg7_ren",
                     "Adjusted GDP growth (%)":"sdg8_adjgrowth",
                     "Victims of modern slavery (per 1,000 population)":"sdg8_slavery",
                     "Adults with an account at a bank or other financial institution or with a mobile":"sdg8_accounts",
                     "Unemployment rate (% of total labor force)":"sdg8_unemp",
                     "Fatal work-related accidents embodied in imports (per 100,000 population)":"sdg8_impacc",
                     "Employment-to-population ratio (%)":"sdg8_empop",
                     "Youth not in employment, education or training (NEET) (% of population aged 15 t":"sdg8_yneet",
                     "Population using the internet (%)":"sdg9_intuse",
                     "Mobile broadband subscriptions (per 100 population)":"sdg9_mobuse",
                     "Logistics Performance Index: Quality of trade and transport-related infrastructu":"sdg9_lpi",
                     "The Times Higher Education Universities Ranking: Average score of top 3 universi":"sdg9_qs",
                     "Scientific and technical journal articles (per 1,000 population)":"sdg9_articles",
                     "Expenditure on research and development (% of GDP)":"sdg9_rdex",
                     "Researchers (per 1,000 employed population)":"sdg9_rdres",
                     "Triadic patent families filed (per million population)":"sdg9_patents",
                     "Gap in internet access by income (percentage points)":"sdg9_netacc",
                     "Women in science and engineering (% of tertiary graduates in science and enginee":"sdg9_womensci",
                     "Gini coefficient adjusted for top income":"sdg10_adjgini",
                     "Palma ratio":"sdg10_palma",
                     "Elderly poverty rate (% of population aged 66 or over)":"sdg10_elder",
                     "Annual mean concentration of particulate matter of less than 2.5 microns in diam":"sdg11_pm25",
                     "Access to improved water source, piped (% of urban population)":"sdg11_pipedwat",
                     "Satisfaction with public transport (%)":"sdg11_transport",
                     "Population with rent overburden (%)":"sdg11_rentover",
                     "Municipal solid waste (kg/capita/day)":"sdg12_msw",
                     "Electronic waste (kg/capita)":"sdg12_ewaste",
                     "Production-based SO₂ emissions (kg/capita)":"sdg12_so2prod",
                     "SO₂ emissions embodied in imports (kg/capita) ":"sdg12_so2import",
                     "Production-based nitrogen emissions (kg/capita)":"sdg12_prodnitro",
                     "Nitrogen emissions embodied in imports (kg/capita)":"sdg12_reacnitro",
                     "Non-recycled municipal solid waste (kg/capita/day)":"sdg12_mswrecycl",
                     "Energy-related CO₂ emissions (tCO₂/capita)":"sdg13_co2pc",
                     "CO₂ emissions embodied in imports (tCO₂/capita)":"sdg13_co2import",
                     "CO₂ emissions embodied in fossil fuel exports (kg/capita)":"sdg13_co2export",
                     "Effective carbon rate (EUR/tCO₂)":"sdg13_ecr",
                     "Mean area that is protected in marine sites important to biodiversity (%) ":"sdg14_cpma",
                     "Ocean Health Index: Clean Waters score (worst 0-100 best)":"sdg14_cleanwat",
                     "Fish caught from overexploited or collapsed stocks (% of total catch)":"sdg14_fishstocks",
                     "Fish caught by trawling (%)":"sdg14_trawl",
                     "Marine biodiversity threats embodied in imports (per million population)":"sdg14_biomar",
                     "Mean area that is protected in terrestrial sites important to biodiversity (%)":"sdg15_cpta",
                     "Mean area that is protected in freshwater sites important to biodiversity (%)":"sdg15_cpfa",
                     "Red List Index of species survival (worst 0-1 best) (Nicaragua yellow on redlist":"sdg15_redlist",
                     "Permanent deforestation (% of forest area, 5-year average)":"sdg15_forchg",
                     "Terrestrial and freshwater biodiversity threats embodied in imports (per million":"sdg15_biofrwter",
                     "Homicides (per 100,000 population)":"sdg16_homicides",
                     "Unsentenced detainees (% of prison population)":"sdg16_detain",
                     "Percentage of population who feel safe walking alone at night in the city or are":"sdg16_safe",
                     "Property Rights (worst 1-7 best)":"sdg16_prs",
                     "Birth registrations with civil authority (% of children under age 5)":"sdg16_u5reg",
                     "Corruption Perception Index (worst 0-100 best)":"sdg16_cpi",
                     "Children involved in child labor (% of population aged 5 to 14)":"sdg16_clabor",
                     "Exports of major conventional weapons (TIV constant million USD per 100,000 popu":"sdg16_weaponsexp",
                     "Press Freedom Index (best 0-100 worst)":"sdg16_rsf",
                     "Persons held in prison (per 100,000 population)":"sdg16_prison",
                     "Government spending on health and education (% of GDP)":"sdg17_govex",
                     "For high-income and all OECD DAC countries: International concessional public fi":"sdg17_oda",
                     "Other countries: Government revenue excluding grants (% of GDP)":"sdg17_govrev",
                     "Corporate Tax Haven Score (best 0-100 worst)":"sdg17_cohaven",
                     "Financial Secrecy Score (best 0-100 worst)":"sdg17_secrecy",
                     "Shifted profits of multinationals (US$ billion)":"sdg17_sprofit"}, inplace=True)

# %%
indicators2020.to_csv("../Project4/indicators2020.csv", index=False)

# %% [markdown]
# ### Checking lengths and missing values

# %% [markdown]
# #### Year 2016

# %%
print(indicators2016.count())
# Out:
# countryname       149
# sdg1_190day_im    139
# sdg1_oecdpov       34
# sdg2_crlyld       145
# sdg2_nue          134
#                  ...
# sdg16_safe        146
# sdg16_u5reg       137
# sdg17_govrev      101
# sdg17_govspd      114
# sdg17_oda          28
# Length: 80, dtype: int64

# %%
sum(indicators2016.isnull().sum())
# Out:
# 2528

# %%
indicators2016.isnull().sum(axis=1)

# %%
indicators2016.to_csv("../Project4/indicators2016.csv", index=False)

# %% [markdown]
# #### Year 2017

# %%
print(indicators2017.count())

# %%
sum(indicators2017.isnull().sum())
# It actually has nans but theyre typed as n.d.

# %%
indicators2017.to_csv("../Project4/indicators2017.csv", index=False)

# %% [markdown]
# #### Year 2018

# %%
print(indicators2018.count())

# %%
sum(indicators2018.isnull().sum())

# %%
indicators2018.to_csv("../Project4/indicators2018.csv", index=False)

# %% [markdown]
# #### Year 2019

# %%
print(indicators2019.count())

# %%
sum(indicators2019.isnull().sum())

# %%
indicators2019.to_csv("../Project4/indicators2019.csv", index=False)

# %% [markdown]
# #### Year 2020

# %%
print(indicators2020.count())

# %%
sum(indicators2020.isnull().sum())

# %%
indicator_list = [col for col in data if col.startswith('sdg')]

# %%
[i for i in indicators2016.columns if i in indicators2017.columns]

# %%
indicators2020.to_csv("../Project4/indicators2020.csv", index=False)

# %%
## Table with information by country
countries = indicator_data.loc[0:192]

# %%
countries.count().unique()

# %%
countries.to_csv("../Documents/Ironhack/countries.csv", index=False)

# %%
data.loc[193:203]

# %%
## Table with information for worldwide regions regions
sum(data.loc[193:203].isnull().sum())

# %%
data.isnull().sum()
